# %%
status = True
while status:
    current_price = 46700
    making_chgs = 5000
    gst = 0.03
    dis_price = 0
    name = input("Enter Customer Name: ") 
    while True:
        if name.isalpha():
            break
        else:
            name = input("Enter Customer Name: ")

    mobile = input("Enter Customer Mobile: ")
    while True:
        if mobile.isdigit():
            break
        else:
            mobile = input("Enter Customer Mobile: ")
    age = input("Enter Age: ")

    while True:
        if age.isdigit():
            break
        else:
            age = input("Enter Age: ")

    gender = input("Enter Gender: ")
    while True:
        if gender.isalpha():
            break
        else:
            gender = input("Enter Age: ")

    produt_name = input("Enter Product name: ")
    while True:
        if produt_name.isalpha():
            break
        else:
            produt_name = input("Enter Product name: ")
            
    product_qty = input("Enter the quantity of product: ")
    while True:
        if product_qty.isdigit():
            break
        else:
            product_qty = input("Enter the quantity of product: ")
    result = current_price * int(product_qty)

    vaccination = input("Enter Yes or No for vaccinated ")
    if vaccination == "yes":
        if int(age) > 65:
            if gender == "male":
                if result < 200000:
                    dis_price = (20 * result)/100
                elif result < 300000:
                    dis_price = (30 * result)/100
                elif result < 500000:
                    dis_price = (50 * result)/100
            else:
                if result < 200000:
                    dis_price = (25 * result)/100
                elif result < 300000:
                    dis_price = (35 * result)/100
                elif result < 500000:
                    dis_price = (55 * result)/100
        else:
            if gender == "male":
                if result < 200000:
                    dis_price = (15 * result)/100
                elif result < 300000:
                    dis_price = (20 * result)/100
                elif result < 500000:
                    dis_price = (40 * result)/100
            else:
                if result < 200000:
                    dis_price = (20 * result)/100
                elif result < 300000:
                    dis_price = (30 * result)/100
                elif result < 500000:
                    dis_price = (50 * result)/100
    else:
        print("No discount of vaccination")

    total_price = result - dis_price
    net_amount = total_price + making_chgs * gst

    choice = input("Do you want to purchase more items : press y for  yes and or press n for no : ").lower()
    
    if choice == 'y' or choice == 'yes':
        status = True
    else:
        status = False
        print("-------------------------Invoice----------------------------")
        print(f"Customer Name : {name}")
        print(f"Customer Age : {age} ")
        print(f"Customer Mobile Number : {mobile} ")
        print(f"Customer Gender : {gender}")

        print(f"Product buy by the customer : {produt_name}")
        print(f"Rate of gold per 10 gram : Rs {current_price}")
        print(f"Quantity purchase by customer in grams : {product_qty} grams")

        print(f"Purchase rate : Rs {result}")
        print(f"Discount : Rs {dis_price}")
        print(f"Price after discount : Rs {total_price}")

        print(f"Making charges per 10 gram :Rs {making_chgs} ")
        print(f"Gst : 3%")

        print(f"Total amount to pay : Rs {net_amount}")
        print("------------------------------------------------------------")
# Out:
# -------------------------Invoice----------------------------
# Customer Name : deep
# Customer Age : 23
# Customer Mobile Number : 65
# Customer Gender : male
# Product buy by the customer : rings
# Rate of gold per 10 gram : Rs 46700
# Quantity purchase by customer in grams : 12 grams
# Purchase rate : Rs 560400
# Discount : Rs 0
# Price after discount : Rs 560400
# Making charges per 10 gram :Rs 5000
# Gst : 3%
# Total amount to pay : Rs 560550.0
# ------------------------------------------------------------
